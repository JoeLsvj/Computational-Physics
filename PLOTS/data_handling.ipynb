# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Total action statistics

# %%
Stat_101 = np.genfromtxt("./A_stat/A_statistics_101.txt", dtype=float)
Stat_201 = np.genfromtxt("./A_stat/A_statistics_201.txt", dtype=float)
Stat_301 = np.genfromtxt("./A_stat/A_statistics_301.txt", dtype=float)
Stat_401 = np.genfromtxt("./A_stat/A_statistics_401.txt", dtype=float)
Stat_501 = np.genfromtxt("./A_stat/A_statistics_501.txt", dtype=float)
Stat_601 = np.genfromtxt("./A_stat/A_statistics_601.txt", dtype=float)
Stat_701 = np.genfromtxt("./A_stat/A_statistics_701.txt", dtype=float)
Stat_801 = np.genfromtxt("./A_stat/A_statistics_801.txt", dtype=float)
Stat_901 = np.genfromtxt("./A_stat/A_statistics_901.txt", dtype=float)

#print(Stat_101)

# %%
fig = plt.figure(figsize=(8,8))
#plt.rc('text', usetex=True)
plt.grid()
plt.axhline(1, color='black', linestyle='--')
plt.axvline(0.4252, color='r', linestyle='--')
plt.xlabel(r'$2^m / N$', fontsize=16)
plt.ylabel(r'$\sigma^2 / N$', fontsize=16)
plt.loglog(Stat_101[:,0], Stat_101[:,2], 'o', mfc='none', label = '101 agents')
plt.loglog(Stat_201[:,0], Stat_201[:,2], '<', mfc='none', label = '201 agents')
plt.loglog(Stat_301[:,0], Stat_301[:,2], '>', mfc='none', label = '301 agents')
plt.loglog(Stat_401[:,0], Stat_401[:,2], 'h', mfc='none', label = '401 agents')
plt.loglog(Stat_501[:,0], Stat_501[:,2], 'd', mfc='none', label = '501 agents')
plt.loglog(Stat_601[:,0], Stat_601[:,2], 's', mfc='none', label = '601 agents')
plt.loglog(Stat_701[:,0], Stat_701[:,2], 'X', mfc='none', label = '701 agents')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(8,8))
#plt.rc('text', usetex=True)
plt.grid()
plt.xlabel(r'$2^m / N$', fontsize=16)
plt.ylabel(r'$\mu / N$', fontsize=16)
plt.semilogx(Stat_101[:,0], Stat_101[:,1], 'o', mfc='none', label = '101 agents')
plt.semilogx(Stat_201[:,0], Stat_201[:,1], '<', mfc='none', label = '201 agents')
plt.semilogx(Stat_301[:,0], Stat_301[:,1], '>', mfc='none', label = '301 agents')
plt.semilogx(Stat_401[:,0], Stat_401[:,1], 'h', mfc='none', label = '401 agents')
plt.semilogx(Stat_501[:,0], Stat_501[:,1], 'd', mfc='none', label = '501 agents')
plt.semilogx(Stat_601[:,0], Stat_601[:,1], 's', mfc='none', label = '601 agents')
plt.semilogx(Stat_701[:,0], Stat_701[:,1], 'X', mfc='none', label = '701 agents')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(15,7))
plt.subplot(121)
plt.xlabel(r'$\alpha = 2^m / N$', fontsize=12)
plt.ylabel(r'$\overline{\langle A(t) \rangle} / N$', fontsize=12)
plt.axvline(0.4252, color='r', linestyle='--')
plt.semilogx(Stat_101[:,0], Stat_101[:,1], 'o', mfc='none', label = '101 agents')
plt.semilogx(Stat_201[:,0], Stat_201[:,1], '<', mfc='none', label = '201 agents')
plt.semilogx(Stat_301[:,0], Stat_301[:,1], '>', mfc='none', label = '301 agents')
plt.semilogx(Stat_401[:,0], Stat_401[:,1], 'h', mfc='none', label = '401 agents')
plt.semilogx(Stat_501[:,0], Stat_501[:,1], 'd', mfc='none', label = '501 agents')
plt.semilogx(Stat_601[:,0], Stat_601[:,1], 's', mfc='none', label = '601 agents')
plt.semilogx(Stat_701[:,0], Stat_701[:,1], 'X', mfc='none', label = '701 agents')
plt.semilogx(Stat_801[:,0], Stat_801[:,1], 'P', mfc='none', label = '801 agents')
plt.semilogx(Stat_901[:,0], Stat_901[:,1], '*', mfc='none', label = '901 agents')
plt.legend(loc = 'lower right')

plt.subplot(122)
plt.xlabel(r'$\alpha = 2^m / N$', fontsize=12)
plt.ylabel(r'$\sigma^2 / N$', fontsize=12)
plt.axhline(1, color='black', linestyle='--')
plt.axvline(0.4252, color='r', linestyle='--')
plt.loglog(Stat_101[:,0], Stat_101[:,2], 'o', mfc='none', label = '101 agents')
plt.loglog(Stat_201[:,0], Stat_201[:,2], '<', mfc='none', label = '201 agents')
plt.loglog(Stat_301[:,0], Stat_301[:,2], '>', mfc='none', label = '301 agents')
plt.loglog(Stat_401[:,0], Stat_401[:,2], 'h', mfc='none', label = '401 agents')
plt.loglog(Stat_501[:,0], Stat_501[:,2], 'd', mfc='none', label = '501 agents')
plt.loglog(Stat_601[:,0], Stat_601[:,2], 's', mfc='none', label = '601 agents')
plt.loglog(Stat_701[:,0], Stat_701[:,2], 'X', mfc='none', label = '701 agents')
plt.loglog(Stat_801[:,0], Stat_801[:,2], 'P', mfc='none', label = '801 agents')
plt.loglog(Stat_901[:,0], Stat_901[:,2], '*', mfc='none', label = '901 agents')
plt.legend()

plt.tight_layout()
plt.savefig("A_stat.png")
plt.show()

# %%
fig = plt.figure(figsize=(15,7))
plt.subplot(121)
plt.xlabel(r'$\alpha = 2^m / N$', fontsize=12)
plt.ylabel(r'$\mu_W / N$', fontsize=12)
plt.axvline(0.4252, color='r', linestyle='--')
plt.loglog(Stat_101[:,0], Stat_101[:,3], 'o', mfc='none', label = '101 agents')
plt.loglog(Stat_201[:,0], Stat_201[:,3], '<', mfc='none', label = '201 agents')
plt.loglog(Stat_301[:,0], Stat_301[:,3], '>', mfc='none', label = '301 agents')
plt.loglog(Stat_401[:,0], Stat_401[:,3], 'h', mfc='none', label = '401 agents')
plt.loglog(Stat_501[:,0], Stat_501[:,3], 'd', mfc='none', label = '501 agents')
plt.loglog(Stat_601[:,0], Stat_601[:,3], 's', mfc='none', label = '601 agents')
plt.loglog(Stat_701[:,0], Stat_701[:,3], 'X', mfc='none', label = '701 agents')
plt.loglog(Stat_801[:,0], Stat_801[:,3], 'P', mfc='none', label = '801 agents')
plt.loglog(Stat_901[:,0], Stat_901[:,3], '*', mfc='none', label = '901 agents')
plt.legend(loc = 'lower right')

plt.subplot(122)
plt.xlabel(r'$\alpha = 2^m / N$', fontsize=12)
plt.ylabel(r'$\sigma^2_W / N$', fontsize=12)
plt.axvline(0.4252, color='r', linestyle='--')
plt.loglog(Stat_101[:,0], Stat_101[:,4], 'o', mfc='none', label = '101 agents')
plt.loglog(Stat_201[:,0], Stat_201[:,4], '<', mfc='none', label = '201 agents')
plt.loglog(Stat_301[:,0], Stat_301[:,4], '>', mfc='none', label = '301 agents')
plt.loglog(Stat_401[:,0], Stat_401[:,4], 'h', mfc='none', label = '401 agents')
plt.loglog(Stat_501[:,0], Stat_501[:,4], 'd', mfc='none', label = '501 agents')
plt.loglog(Stat_601[:,0], Stat_601[:,4], 's', mfc='none', label = '601 agents')
plt.loglog(Stat_701[:,0], Stat_701[:,4], 'X', mfc='none', label = '701 agents')
plt.loglog(Stat_801[:,0], Stat_801[:,4], 'P', mfc='none', label = '801 agents')
plt.loglog(Stat_901[:,0], Stat_901[:,4], '*', mfc='none', label = '901 agents')
plt.legend()

plt.tight_layout()
plt.savefig("W_stat.png")
plt.show()

# %% [markdown]
# ### total action time series (with random back)

# %%
# s = 5
A_t_2_1001 = np.genfromtxt("./A_t/A_t_ 2_1001.txt", dtype=int)
A_t_5_1001 = np.genfromtxt("./A_t/A_t_ 5_1001.txt", dtype=int)
A_t_10_1001 = np.genfromtxt("./A_t/A_t_10_1001.txt", dtype=int)
A_t_15_1001 = np.genfromtxt("./A_t/A_t_15_1001.txt", dtype=int)

# s = 2
A_t_2_301= np.genfromtxt("./A_t/A_t_ 2_301.txt", dtype=int)  
A_t_5_301 = np.genfromtxt("./A_t/A_t_ 5_301.txt", dtype=int)
A_t_10_301 = np.genfromtxt("./A_t/A_t_10_301.txt", dtype=int)
A_t_15_301 = np.genfromtxt("./A_t/A_t_15_301.txt", dtype=int)           # runs = 10000 for all

# %%
fig = plt.figure(figsize=(12,6))
plt.subplot(311)
plt.xlim([0, 250])
plt.ylim([-1000, 1000])
plt.ylabel(r'$A(t)$', fontsize=12)
plt.plot(A_t_2_1001[0:250,0], A_t_2_1001[0:250,1], label = 'm = 2')
plt.legend()

plt.subplot(312)
plt.xlim([0, 250])
plt.ylim([-1000, 1000])
plt.ylabel(r'$A(t)$', fontsize=12)
plt.plot(A_t_5_1001[0:250,0], A_t_5_1001[0:250,1], label = 'm = 5')
plt.legend()

plt.subplot(313)
plt.xlim([0, 250])
plt.ylim([-1000, 1000])
plt.xlabel(r'$t$', fontsize=12)
plt.ylabel(r'$A(t)$', fontsize=12)
plt.plot(A_t_10_1001[0:250,0], A_t_10_1001[0:250,1], label = 'm = 10')
plt.legend()

#plt.subplot(414)
#plt.xlabel(r'$t$', fontsize=16)
#plt.ylabel(r'$A(t)$', fontsize=16)
#plt.plot(A_t_15_301[0:500,0], A_t_15_301[0:500,1], label = 'm = 15')
#plt.legend()

plt.tight_layout()
plt.savefig("A_t_1001.png")
plt.show()

# %%
fig = plt.figure(figsize=(12,7))
plt.subplot(311)
plt.xlim([0, 250])
plt.ylim([-180, 180])
plt.ylabel(r'$A(t)$', fontsize=16)
plt.plot(A_t_2_301[0:250,0], A_t_2_301[0:250,1], label = 'm = 2')
plt.legend()

plt.subplot(312)
plt.xlim([0, 250])
plt.ylim([-180, 180])
plt.ylabel(r'$A(t)$', fontsize=16)
plt.plot(A_t_5_301[0:250,0], A_t_5_301[0:250,1], label = 'm = 5')
plt.legend()

plt.subplot(313)
plt.xlim([0, 250])
plt.ylim([-180, 180])
plt.xlabel(r'$t$', fontsize=16)
plt.ylabel(r'$A(t)$', fontsize=16)
plt.plot(A_t_15_301[0:250,0], A_t_15_301[0:250,1], label = 'm = 15')
plt.legend()

#plt.subplot(414)
#plt.xlabel(r'$t$', fontsize=16)
#plt.ylabel(r'$A(t)$', fontsize=16)
#plt.plot(A_t_15_101[0:500,0], A_t_15_101[0:500,1], label = 'm = 15')
#plt.legend()

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(18,6))
plt.subplot(131)
plt.xlabel('$A$')
plt.ylabel('count')
plt.hist(A_t_15_1001[:,1], bins=200, label = 'm = 15')
plt.legend()

plt.subplot(132)
plt.xlabel('$A$')
plt.ylabel('count')
plt.hist(A_t_10_1001[:,1], bins=200, label = 'm = 10')
plt.legend()

plt.subplot(133)
plt.xlabel('$A$')
plt.ylabel('count')
plt.hist(A_t_5_1001[:,1], bins=500, label = 'm = 5')
plt.legend()

plt.savefig("A_hist_1001.png")
plt.show()

# %%
plt.figure(figsize=(18,6))
plt.subplot(131)
plt.xlabel('$A$')
plt.ylabel('count')
plt.hist(A_t_15_301[:,1], bins=150)

plt.subplot(132)
plt.xlabel('$A$')
plt.ylabel('count')
plt.hist(A_t_5_301[:,1], bins=200)

plt.subplot(133)
plt.xlabel('$A$')
plt.ylabel('count')
plt.hist(A_t_2_301[:,1], bins=200)

plt.show()

# %% [markdown]
# ### total action time series with average payoff

# %%
# s = 5
A_t_av_5_1001 = np.genfromtxt("./A_t_av_ 5_1001.txt", dtype=int)
A_t_av_6_1001 = np.genfromtxt("./A_t_av_6_1001.txt", dtype=int)
A_t_av_7_1001 = np.genfromtxt("./A_t_av_7_1001.txt", dtype=int)
A_t_av_8_1001 = np.genfromtxt("./A_t_av_8_1001.txt", dtype=int)

# s = 2
A_t_av_2_5_1001 = np.genfromtxt("./A_t_av_26_1001.txt", dtype=int)
A_t_av_2_6_1001 = np.genfromtxt("./A_t_av_27_1001.txt", dtype=int)
A_t_av_2_7_1001 = np.genfromtxt("./A_t_av_28_1001.txt", dtype=int)
A_t_av_2_8_1001 = np.genfromtxt("./A_t_av_29_1001.txt", dtype=int)

# %%
plt.figure(figsize=(18,6))
plt.subplot(131)
plt.xlabel('$A$')
plt.ylabel('count')
plt.hist(A_t_av_2_5_1001[:,1], bins=150)

plt.subplot(132)
plt.xlabel('$A$')
plt.ylabel('count')
plt.hist(A_t_av_2_6_1001[:,1], bins=200)

plt.subplot(133)
plt.xlabel('$A$')
plt.ylabel('count')
plt.hist(A_t_av_2_7_1001[:,1], bins=200)

plt.show()

# %%
plt.figure(figsize=(18,6))
plt.subplot(121)
plt.xlabel('$A$')
plt.ylabel('count')
plt.xlim([-75, 75])
plt.ylim([0,2000])
plt.hist(A_t_av_5_1001[:,1], bins=3000)

plt.subplot(122)
plt.xlabel('$A$')
plt.ylabel('count')
plt.xlim([-150, 150])
plt.ylim([0,2000])
plt.hist(A_t_av_6_1001[:,1], bins=2000)

plt.show()

# %% [markdown]
# ### strategies in the limit

# %%
st_hist = np.genfromtxt('./winrate_histo/strategies_scores.txt', dtype = float)
st_hist_2 = np.genfromtxt('./winrate_histo/strategies_scores_2.txt', dtype = float)
st_hist_3 = np.genfromtxt('./strategies_scores_3.txt', dtype = float)

plt.figure(figsize=(12,6))

plt.subplot(121)
plt.xlabel('win rate')
plt.ylabel('count')
plt.title("N=1001, s=10, g(A(t)) = sgn[A(t)]")
plt.hist(st_hist[0:10010], histtype='step', bins = 25, color = 'blue', label = '200 time steps')
plt.hist(st_hist[10010:20010], histtype='step', bins = 20, color = 'green', label = '1000 time steps')
plt.hist(st_hist[20020:30030], histtype='step', bins = 10, color = 'purple', label = '5000 time steps')
plt.legend()

plt.subplot(122)
plt.xlabel('average score')
plt.ylabel('count')
plt.title("N=1001, s=10, g(A(t)) = A(t)")
plt.hist(st_hist_3[0:10010], histtype='step', bins = 80, color = 'blue', label = '200 time steps')
plt.hist(st_hist_3[10010:20010], histtype='step', bins = 45, color = 'green', label = '1000 time steps')
plt.hist(st_hist_3[20020:30030], histtype='step', bins = 30, color = 'purple', label = '5000 time steps')
plt.legend()

plt.savefig("strategy_hist.png")
plt.show()

# %% [markdown]
# ### strategy-winrate behaviour

# %%
st_behave_1001 = np.genfromtxt('./strategies_winrate/strategies_winrate_1001_5.txt', dtype= float)
st_behave_301 = np.genfromtxt('./strategies_winrate/strategies_winrate_301_8.txt', dtype= float)

plt.figure(figsize=(16,8))

plt.subplot(121)
plt.xlabel('number of strategies', fontsize=12)
plt.ylabel('Winners Rate', fontsize=12)
plt.axvline(1, color = 'red', linestyle='--')
plt.plot(st_behave_1001[0:15,0], st_behave_1001[0:15,2], 'o-', mfc='none', label = 'N = 1001, m = 5')
plt.plot(st_behave_1001[15:30,0], st_behave_1001[15:30,2], 'o-', mfc='none', label = 'N = 1001, m = 5')
plt.plot(st_behave_1001[30:45,0], st_behave_1001[30:45,2], 'o-', mfc='none', label = 'N = 1001, m = 5')
plt.legend()

plt.subplot(122)
plt.xlabel('number of strategies', fontsize=12)
plt.ylabel('Winners Rate', fontsize=12)
plt.axvline(2, color = 'red', linestyle='--')
plt.plot(st_behave_301[0:25,0], st_behave_301[0:25,2], 'o-', mfc='none', label = 'N = 301, m = 8')
plt.plot(st_behave_301[25:50,0], st_behave_301[25:50,2], 'o-', mfc='none', label = 'N = 301, m = 8')
plt.plot(st_behave_301[50:75,0], st_behave_301[50:75,2], 'o-', mfc='none', label = 'N = 301, m = 8')
plt.legend()

plt.savefig("strategy_winrate.png")
plt.show()

# %% [markdown]
# ### memory-winrate behaviour

# %%
memory_behave_1001 = np.genfromtxt('./memory_winrate_1001_5.txt', dtype= float)
memory_behave_301 = np.genfromtxt('./memory_winrate_301_2.txt', dtype= float)

plt.figure(figsize=(16,8))

plt.subplot(121)
plt.xlabel('memory', fontsize=12)
plt.ylabel('Winners Rate', fontsize=12)
plt.axhline(0.487, color = 'red', linestyle='--')
plt.plot(memory_behave_1001[:,0], memory_behave_1001[:,2], 'o', mfc='none', label = 'N = 1001, s = 5')
plt.legend()

plt.subplot(122)
plt.xlabel('memory', fontsize=12)
plt.ylabel('Winners Rate', fontsize=12)
plt.axhline(0.477, color = 'red', linestyle='--')
plt.plot(memory_behave_301[:,0], memory_behave_301[:,2], 'o', mfc='none', label = 'N = 301, s = 2')
plt.legend()

plt.savefig("memory_winrate.png")
plt.show()

# %%
memory_mixed_1001 = np.genfromtxt('./memory_scores_mixed.txt', dtype= float)

plt.figure(figsize=(8,8))

plt.xlabel('memory', fontsize=12)
plt.ylabel('win rate', fontsize=12)
plt.axhline(0.5, color = 'red', linestyle='--')
plt.plot(memory_mixed_1001[:,0], memory_mixed_1001[:,1], 'o', mfc='none', label = 'N = 1001, s = 5')
plt.legend()

plt.savefig("mixed_memory_winrate.png")
plt.show()

# %% [markdown]
# ### evolution

# %%
evo_test = np.genfromtxt("./evo_test.txt", dtype = float)

fig = plt.figure(figsize=(16,8))
plt.xlabel(r'$t$', fontsize=16)
plt.ylabel(r'$A(t)$', fontsize=16)
plt.plot(evo_test[:, 0], evo_test[:, 1], label = 'N = 1001, m = 5, s = 2')
plt.legend()

plt.savefig("A_t_evo_1.png")
plt.show()

# %%
evo_test_1001 = np.genfromtxt("./evo_test_1001.txt", dtype = float)

fig = plt.figure(figsize=(16,8))
plt.xlabel(r'$t$', fontsize=16)
plt.ylabel(r'$A(t)$', fontsize=16)
plt.plot(evo_test_1001[:50000, 0], evo_test_1001[:50000, 1], label = 'N = 1001, s = 2')
plt.legend()

plt.savefig("A_t_evo_2.png")
plt.show()

# %%
evo_memory_1001 = np.genfromtxt("./evo_memory_1001.txt", dtype = float)
evo_memory_701 = np.genfromtxt("./evo_memory_701.txt", dtype = float)
evo_memory_501 = np.genfromtxt("./evo_memory_501.txt", dtype = float)

fig = plt.figure(figsize=(10,8))
plt.xlabel(r'$t$', fontsize=16)
plt.ylabel('memory average', fontsize=16)
plt.plot(evo_memory_1001[:, 0], evo_memory_1001[:, 1], label = 'N = 1001, s = 2')
plt.plot(evo_memory_701[:, 0], evo_memory_701[:, 1], label = 'N = 701, s = 2')
plt.plot(evo_memory_501[:, 0], evo_memory_501[:, 1], label = 'N = 501, s = 2')
plt.legend()

plt.savefig("memory_average.png")
plt.show()

# %% [markdown]
# ### market mechanism

# %%
market_A_t_1001_501_5 = np.genfromtxt("./market_A_T_1001_501_5.txt")
market_Nsp_1001_501_5 = np.genfromtxt("./market_Nsp_1001_501_5.txt")

fig = plt.figure(figsize=(10,8))
plt.subplot(211)
plt.xlabel(r'$t$', fontsize=12)
plt.ylabel(r'$A(t)$', fontsize=12)
plt.plot(market_A_t_1001_501_5[:3000, 0], market_A_t_1001_501_5[:3000, 1], label = 'N = 1001, s = 2')
plt.legend()

plt.subplot(212)
plt.xlabel(r'$t$', fontsize=12)
plt.ylabel('active speculators', fontsize=12)
plt.plot(market_Nsp_1001_501_5[:3000, 0], market_Nsp_1001_501_5[:3000, 1], label = 'N = 1001, s = 2')
plt.legend()

plt.savefig("A_t_Nsp.png")
plt.show()

# %%
Nsp_gain_256p = np.genfromtxt("./Nsp_gain_256p.txt", dtype = float)

fig = plt.figure(figsize=(10,8))
plt.xlabel('number of speculators / 2^m', fontsize=12)
plt.ylabel('average gain', fontsize=12)
plt.plot(Nsp_gain_256p[:10, 0], Nsp_gain_256p[:10, 1], 'o-', label = 'speculators')
plt.plot(Nsp_gain_256p[:10, 0], Nsp_gain_256p[:10, 2], 'o-', label = 'producers')
plt.legend()

plt.savefig("Nsp_gain.png")
plt.show()
